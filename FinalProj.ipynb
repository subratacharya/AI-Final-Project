# %%
Names = "Zafar Khan. Subrat Acharya, and Michael Dobroski"

# %%
# imports
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import seaborn as sns
from sklearn import (datasets, neighbors,
                     naive_bayes,
                     model_selection as skms,
                     linear_model, dummy,
                     metrics, preprocessing)
from sklearn import preprocessing
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# %%
car_train_plus_val_df = pd.read_csv("cartrain.csv")
car_test_df = pd.read_csv("cartest.csv")

#Useless Coloumns??
car_train_plus_val_df = car_train_plus_val_df.drop(['county'],axis=1)
car_train_plus_val_df = car_train_plus_val_df.drop(['url'],axis=1)
car_train_plus_val_df = car_train_plus_val_df.drop(['region_url'],axis=1)
#car_train_plus_val_df = car_train_plus_val_df.drop(['image_url'],axis=1)

#Fill in Missing Data
car_train_plus_val_df['condition'] = car_train_plus_val_df['condition'].replace({np.nan:"new"})


#Convert images

#Pipeline Steps
#scaler = skpre.StandardScaler()
            
#dummy = pd.get_dummies(car_train_plus_val_df['region']) #State, paint color, type, size, drive, Vin
                                                           #model, region, transmission, title_status, fuel
                                                           #cylinders, condition, manufacturer
display(car_train_plus_val_df)
# Out:
#             id        region  price    year manufacturer           model  \
# 0            1    greensboro  10299  2012.0        acura              tl
# 1            2    greensboro      0  2011.0          bmw             335
# 2            4    greensboro   3995  2004.0        honda         element
# 3            6    greensboro  12995  2015.0          kia        sportage
# 4            7    greensboro  10995  2014.0    chevrolet        traverse
# ...        ...           ...    ...     ...          ...             ...
# 313826  431692     san diego  10997  2017.0       toyota         corolla
# 313827  431693   chattanooga  12990  2013.0       toyota            rav4
# 313828  431694     san diego      0  2018.0       toyota  camry le sedan
# 313829  431695  philadelphia   5995  2007.0     infiniti               g
# 313830  431696     san diego      0  2012.0    chevrolet          camaro
#
#         condition    cylinders fuel  odometer  ... transmission  \
# ...

# %%
pipe = pipeline.Pipeline(steps=[('scaler', scaler), 
                               ])
